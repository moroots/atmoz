# %%
import atmoz

# %%
from atmoz.lidar.TOLNet_V2 import TOLNet

# %%
tolnet = TOLNet()

# %%
tolnet.products
# Out:
#    product_type_name                                        description  \
# id
# 1            O3Lidar  Vertical profiles of ozone using a lidar techn...
# 2            Surface           In-situ measurements of surface products
# 3              Other  Data that is not ozone lidar or surface in-sit...
# 4              HIRES      Highest temporal and vertical resolution data
# 5             CALVAL  Optimized for specific comparative evaluation ...
# 6               CLIM       Optimized for climatology and trends studies
# 8             Legacy  generic HDF or TOLNet ASCII data products (Con...
#
#     parent_id  display_order show_on_graph_page
# id
# 1         NaN              1                  t
# 2         NaN              2                  f
# 3         NaN              3                  f
# 4         1.0              1                  t
# 5         1.0              2                  t
# 6         1.0              3                  t
# ...

# %%
tolnet.file_types
# Out:
#                        file_type_name  \
# id
# 1                HDF GEOMS (Standard)
# 2   Generic HDF (Experimental/Legacy)
# 3                               ASCII
# 4                               Image
# 5                                 Raw
#
#                                           description  display_order public
# id
# 1   Data in EVDC GEOMS-standard Hierarchical Data ...              1      t
# 2   Experimental or Legacy Files. Data in generic ...              4      t
# 3   Surface Data in ICARTT or legacy TOLNet text f...              2      t
# 4   Data displayed as an image (e.g. png, pdf, jpg...              3      t
# 5                     Raw data uploaded as a zip file              4      f

# %%
tolnet.instrument_groups
# Out:
#    instrument_group_name folder_name  \
# id
# 1                   ECCC        eccc
# 2              NASA GSFC        gsfc
# 3         NASA JPL TMTOL         jpl
# 4              NASA LaRC        larc
# 5          NOAA ESRL/CSL         csl
# 6                    UAH         uah
# 7        NASA JPL SMOL-1    jplsmol1
# 8        NASA JPL SMOL-2    jplsmol2
# 9                   CCNY        ccny
# 10             Hampton U          hu
# 11       NASA JPL SMOL-3    jplsmol3
# 12       NASA JPL SMOL-4    jplsmol4
# 13       NASA JPL SMOL-5    jplsmol5
#
#                                           description  display_order  \
# id
# 1   Environment and Climate Change Canada (mobile ...             50
# 2   NASA Goddard Space Flight Center (mobile instr...              2
# 3   NASA Jet Propulsion Laboratory (stationary ins...             35
# 4    NASA Langley Research Center (mobile instrument)              4
# 5   NOAA Earth System Research Laboratories - Chem...             60
# ...

# %%
tolnet.processing_types
# Out:
#            processing_type_name  \
# id
# 1   Centrally Processed (GLASS)
# 2            In-House Processed
# 3                   Unprocessed
#
#                                           description  display_order public  \
# id
# 1   Files that have been Centrally Processed using...             10      t
# 2   Files that have been processed In House by the...             20      t
# 3                  Files that have been not processed             30      f
#
#    show_on_graph_page
# id
# 1                   t
# 2                   t
# 3                   f
