# %% [markdown]
# # Main Title
# - Author: Maurice Roots
# - Date Created: 2026-06-08 17:46
# - Last Updated: 2026-06-08 17:46
# ---

# %%
import importlib 
from atmoz import lidar

importlib.reload(lidar)
# Out:
# <module 'atmoz.lidar' from 'E:\\Projects\\atmoz\\atmoz\\lidar\\__init__.py'>

# %%
tolnet = lidar.TOLNET()

# %%
params = {
    "min_date": "2025-06-01", 
    "max_date": "2025-08-01",
    "instrument_group": [7, 8, 2],
    "product_type": [4],
    "processing_type": [1],
    }

tolnet.import_data(**params)
# Out:
# Downloading TOLNet Data: 100%|██████████████████████████████████████| 99/99 [00:34<00:00,  2.86it/s]

# %%
for key, item in tolnet.data.items():
    print(key)
    tolnet.plot_curtain(item, title=key)
# Out:
# ('NASA GSFC', 'Centrally Processed (GLASS)', '38.98x-76.83')
# E:\Projects\atmoz\atmoz\resources\plot_utilities.py:85: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   result = target(**kwargs)
# ('NASA JPL SMOL-2', 'Centrally Processed (GLASS)', '39.24x-76.363')
# E:\Projects\atmoz\atmoz\resources\plot_utilities.py:85: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   result = target(**kwargs)
# ('NASA JPL SMOL-1', 'Centrally Processed (GLASS)', '39.32x-76.586')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 for key, item in tolnet.data.items():
#       2     print(key)
# ----> 3     tolnet.plot_curtain(item, title=key)
#
# File E:\Projects\atmoz\atmoz\lidar\dev_TOLNET.py:617, in TOLNET.plot_curtain(self, data, **kwargs)
#     614     continue
#     616 if time_resolution == "auto":
# --> 617     resolution = np.min([df.index[i] - df.index[i - 1] for i in range(1, len(df))])
#     618     df = df.resample(f"{resolution.seconds}s").mean()
#     619 else:
#
# File E:\Projects\atmoz\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:3261, in min(a, axis, out, keepdims, initial, where)
#    3149 @array_function_dispatch(_min_dispatcher)
#    3150 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3151         where=np._NoValue):
#    3152     """
#    3153     Return the minimum of an array or minimum along an axis.
#    3154
#    (...)   3259     6
#    3260     """
# -> 3261     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3262                           keepdims=keepdims, initial=initial, where=where)
#
# File E:\Projects\atmoz\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:83, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      80         else:
#      81             return reduction(axis=axis, out=out, **passkwargs)
# ---> 83 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
tolnet.processing_types

# %%
tolnet.file_types

# %%
tolnet.products

# %%
tolnet.instrument_groups
