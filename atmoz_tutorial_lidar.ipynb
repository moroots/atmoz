# %% [markdown]
# # Main Title
# - Author: Maurice Roots
# - Date Created: 2026-06-08 17:46
# - Last Updated: 2026-06-08 17:46
# ---

# %%
import importlib 
from atmoz import lidar

importlib.reload(lidar)
# Out:
# <module 'atmoz.lidar' from 'E:\\Projects\\atmoz\\atmoz\\lidar\\__init__.py'>

# %%
tolnet = lidar.TOLNet()

# %%
tolnet.import_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tolnet.import_data()
#
# AttributeError: 'TOLNET' object has no attribute 'import_data'
